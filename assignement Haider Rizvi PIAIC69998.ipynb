# %%
print("haider")
# Out:
# haider

# %%
#assignemt of Haider Rizvi Roll No. PIAIC69998 Batch-3, Islamabad
print(2**3/2*6-4*(3-4/2)) #2**3/2*6-4*(3-2) 1st solve paranthesis
                          #8/2*6-4(1)   #then solve power of 2^3=8
                          #8/2*6-4   48/2-4
                          # 24-4=20
# Out:
# 20.0

# %%
#assignemt of Haider Rizvi Roll No. PIAIC69998 Batch-3, Islamabad 
#strings methods
name1="Haider Rizvi"
print(name1)
# Out:
# Haider Rizvi

# %%
dir (name1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
print(name1.capitalize())
# Out:
# Haider rizvi

# %%
print(name1.casefold())
# Out:
# haider rizvi

# %%
print(name1.center(2))
# Out:
# Haider Rizvi

# %%
print(name1.count('H'))
# Out:
# 1

# %%
print(name1.encode())
# Out:
# b'Haider Rizvi'

# %%
str = '\nhaid\ter'

# no argument is passed
# default tabsize is 8
name2 = str.expandtabs()

print(name2)
# Out:
# haid    er

# %%
print('Tabsize 2:', str.expandtabs(2))
# Out:
# Tabsize 2:
# haid  er

# %%
print('Tabsize 4:', str.expandtabs(4))
# Out:
# Tabsize 4:
# haid    er

# %%
print('Tabsize 9:', str.expandtabs(9))
# Out:
# Tabsize 9:
# haid     er

# %%
quote = 'I am Haider Student PIAIC'


print(quote.find('small things', 6, 20))
# Out:
# -1

# %%
print(quote.find('o small ', 10, -1))
# Out:
# -1

# %%
song = 'cold, cold heart'
print (song.replace('cold', 'hurt'))
# Out:
# hurt, hurt heart

# %%
sentence = 'Python programming is fun.'

result = sentence.index('is fun')
print("Substring 'is fun':", result)
# Out:
# Substring 'is fun': 19

# %%
numList = ['1', '2', '3', '4']
seperator = ', '
print(seperator.join(numList))
# Out:
# 1, 2, 3, 4

# %%
text= 'PIAIC belongs to Artificial Intelligence'

# splits at space
print(text.split())
# Out:
# ['PIAIC', 'belongs', 'to', 'Artificial', 'Intelligence']

# %%
text = "Iam's an engineer, isn't I am?"
print(text.title())
# Out:
# Iam'S An Engineer, Isn'T I Am?

# %%
# example string
string = "THIS SHOULD ALL BE LOWERCASE."
print(string.swapcase())
# Out:
# this should all be lowercase.

# %%
string = "this should all be uppercase."
print(string.swapcase())
# Out:
# THIS SHOULD ALL BE UPPERCASE.

# %%
string = "ThIs ShOuLd Be MiXeD cAsEd."
print(string.swapcase())
# Out:
# tHiS sHoUlD bE mIxEd CaSeD.
